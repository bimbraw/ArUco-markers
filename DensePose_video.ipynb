# %% [markdown]
# <a href="https://colab.research.google.com/github/bimbraw/Aruco-Markers/blob/master/DensePose_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pose Detection with DensePose
#
# This notebook uses an open source project [facebookresearch/DensePose](https://github.com/facebookresearch/DensePose) to detect multi person poses on a test image.
#
# For other deep-learning Colab notebooks, visit [tugstugi/dl-colab-notebooks](https://github.com/tugstugi/dl-colab-notebooks).
#
#
# ## Install DensePose
#
# Installing the DensePose seems to be very tricky. For more information, see [http://linkinpark213.com/2018/11/18/densepose-minesweeping/](http://linkinpark213.com/2018/11/18/densepose-minesweeping/).
#
# First, we are going to install an Anaconda with some fixed dependencies:

# %%
import os
from os.path import exists, join, basename, splitext

# install Anaconda Python 2.7 to control the dependencies
# see for more info: 
if not exists('anaconda2'):
  # !wget -q https://repo.anaconda.com/archive/Anaconda2-2019.03-Linux-x86_64.sh
  # !chmod +x Anaconda2-2019.03-Linux-x86_64.sh
  # !bash ./Anaconda2-2019.03-Linux-x86_64.sh -b -f -p /content/anaconda2
  # set PATH environment variable
  os.environ['PATH'] = "/content/anaconda2/bin:" + os.environ['PATH']
  # install PyTorch
  # !conda install -y pyyaml=3.12
  # !conda install -y mkl-include
  # !conda install -y pytorch=1.0.1 torchvision cudatoolkit=10.0 -c pytorch
  # !ln -s /content/anaconda2/lib/python2.7/site-packages/torch/lib/ /content/anaconda2/lib/python2.7/site-packages/
  # install GCC 4.9
  # !conda install -y -c serge-sans-paille gcc_49
  # !ln -fs /content/anaconda2/lib/libmpfr.so /content/anaconda2/lib/libmpfr.so.4
  os.environ['CC'] = '/content/anaconda2/bin/gcc-4.9'
  os.environ['CXX'] = '/content/anaconda2/bin/g++-4.9'
  # protobuf 3.5
  #!apt-get -qq remove -y protobuf-compiler
  # !conda install -y protobuf=3.5
  # pycocotools
  # !conda install -y -c conda-forge pycocotools
  
# we need some headers from the pytorch source
if not exists('pytorch'):
  # !git clone -q --depth 1 --recursive -b v1.0.1 https://github.com/pytorch/pytorch
# Out:
# PREFIX=/content/anaconda2
# installing: python-2.7.16-h9bab390_0 ...
# using -f (force) option
# Python 2.7.16 :: Anaconda, Inc.
# installing: conda-env-2.6.0-1 ...
# using -f (force) option
# installing: blas-1.0-mkl ...
# using -f (force) option
# installing: ca-certificates-2019.1.23-0 ...
# using -f (force) option
# installing: intel-openmp-2019.3-199 ...
# using -f (force) option
# installing: libgcc-ng-8.2.0-hdf63c60_1 ...
# using -f (force) option
# installing: libgfortran-ng-7.3.0-hdf63c60_0 ...
# using -f (force) option
# installing: libstdcxx-ng-8.2.0-hdf63c60_1 ...
# using -f (force) option
# installing: bzip2-1.0.6-h14c3975_5 ...
# using -f (force) option
# installing: expat-2.2.6-he6710b0_0 ...
# using -f (force) option
# installing: fribidi-1.0.5-h7b6447c_0 ...
# using -f (force) option
# installing: gmp-6.1.2-h6c8ec71_1 ...
# using -f (force) option
# installing: graphite2-1.3.13-h23475e2_0 ...
# using -f (force) option
# installing: icu-58.2-h9c2bf20_1 ...
# using -f (force) option
# installing: jbig-2.1-hdba287a_0 ...
# using -f (force) option
# installing: jpeg-9b-h024ee3a_2 ...
# using -f (force) option
# installing: libffi-3.2.1-hd88cf55_4 ...
# using -f (force) option
# installing: liblief-0.9.0-h7725739_2 ...
# using -f (force) option
# installing: libsodium-1.0.16-h1bed415_0 ...
# using -f (force) option
# installing: libtool-2.4.6-h7b6447c_5 ...
# using -f (force) option
# installing: libuuid-1.0.3-h1bed415_2 ...
# using -f (force) option
# installing: libxcb-1.13-h1bed415_1 ...
# using -f (force) option
# installing: lz4-c-1.8.1.2-h14c3975_0 ...
# using -f (force) option
# installing: lzo-2.10-h49e0be7_2 ...
# using -f (force) option
# installing: mkl-2019.3-199 ...
# using -f (force) option
# installing: ncurses-6.1-he6710b0_1 ...
# using -f (force) option
# installing: openssl-1.1.1b-h7b6447c_1 ...
# using -f (force) option
# installing: patchelf-0.9-he6710b0_3 ...
# using -f (force) option
# installing: pcre-8.43-he6710b0_0 ...
# using -f (force) option
# installing: pixman-0.38.0-h7b6447c_0 ...
# using -f (force) option
# installing: snappy-1.1.7-hbae5bb6_3 ...
# using -f (force) option
# installing: xz-5.2.4-h14c3975_4 ...
# using -f (force) option
# installing: yaml-0.1.7-had09818_2 ...
# using -f (force) option
# installing: zlib-1.2.11-h7b6447c_3 ...
# using -f (force) option
# installing: blosc-1.15.0-hd408876_0 ...
# using -f (force) option
# installing: glib-2.56.2-hd408876_0 ...
# using -f (force) option
# installing: hdf5-1.10.4-hb1b8bf9_0 ...
# using -f (force) option
# installing: libedit-3.1.20181209-hc058e9b_0 ...
# using -f (force) option
# installing: libpng-1.6.36-hbc83047_0 ...
# using -f (force) option
# installing: libssh2-1.8.0-h1ba5d50_4 ...
# using -f (force) option
# installing: libxml2-2.9.9-he19cac6_0 ...
# using -f (force) option
# installing: mpfr-4.0.1-hdf1c602_3 ...
# using -f (force) option
# installing: pandoc-2.2.3.2-0 ...
# using -f (force) option
# installing: readline-7.0-h7b6447c_5 ...
# using -f (force) option
# installing: tk-8.6.8-hbc83047_0 ...
# using -f (force) option
# installing: zeromq-4.3.1-he6710b0_3 ...
# using -f (force) option
# installing: zstd-1.3.7-h0b5b093_0 ...
# using -f (force) option
# installing: dbus-1.13.6-h746ee38_0 ...
# using -f (force) option
# installing: freetype-2.9.1-h8a8886c_1 ...
# using -f (force) option
# installing: gstreamer-1.14.0-hb453b48_1 ...
# using -f (force) option
# installing: krb5-1.16.1-h173b8e3_7 ...
# using -f (force) option
# installing: libarchive-3.3.3-h5d8350f_5 ...
# using -f (force) option
# installing: libtiff-4.0.10-h2733197_2 ...
# using -f (force) option
# installing: libxslt-1.1.33-h7d1a2b0_0 ...
# using -f (force) option
# installing: mpc-1.1.0-h10f8cd9_1 ...
# using -f (force) option
# installing: sqlite-3.27.2-h7b6447c_0 ...
# using -f (force) option
# installing: unixodbc-2.3.7-h14c3975_0 ...
# using -f (force) option
# installing: fontconfig-2.13.0-h9420a91_0 ...
# using -f (force) option
# installing: gst-plugins-base-1.14.0-hbbd80ab_1 ...
# using -f (force) option
# installing: libcurl-7.64.0-h20c2e04_2 ...
# using -f (force) option
# installing: alabaster-0.7.12-py27_0 ...
# using -f (force) option
# installing: asn1crypto-0.24.0-py27_0 ...
# using -f (force) option
# installing: atomicwrites-1.3.0-py27_1 ...
# using -f (force) option
# installing: attrs-19.1.0-py27_1 ...
# using -f (force) option
# installing: backports-1.0-py27_1 ...
# using -f (force) option
# installing: backports_abc-0.5-py27h7b3c97b_0 ...
# using -f (force) option
# installing: bitarray-0.8.3-py27h14c3975_0 ...
# using -f (force) option
# installing: boto-2.49.0-py27_0 ...
# using -f (force) option
# installing: cairo-1.14.12-h8948797_3 ...
# using -f (force) option
# installing: cdecimal-2.3-py27h14c3975_3 ...
# using -f (force) option
# installing: certifi-2019.3.9-py27_0 ...
# using -f (force) option
# installing: chardet-3.0.4-py27_1 ...
# using -f (force) option
# installing: click-7.0-py27_0 ...
# using -f (force) option
# installing: cloudpickle-0.8.0-py27_0 ...
# using -f (force) option
# installing: colorama-0.4.1-py27_0 ...
# using -f (force) option
# installing: contextlib2-0.5.5-py27hbf4c468_0 ...
# using -f (force) option
# installing: curl-7.64.0-hbc83047_2 ...
# using -f (force) option
# installing: dask-core-1.1.4-py27_1 ...
# using -f (force) option
# installing: decorator-4.4.0-py27_1 ...
# using -f (force) option
# installing: defusedxml-0.5.0-py27_1 ...
# using -f (force) option
# installing: docutils-0.14-py27hae222c1_0 ...
# using -f (force) option
# installing: enum34-1.1.6-py27_1 ...
# using -f (force) option
# installing: et_xmlfile-1.0.1-py27h75840f5_0 ...
# using -f (force) option
# installing: fastcache-1.0.2-py27h14c3975_2 ...
# using -f (force) option
# installing: filelock-3.0.10-py27_0 ...
# using -f (force) option
# installing: funcsigs-1.0.2-py27h83f16ab_0 ...
# using -f (force) option
# installing: functools32-3.2.3.2-py27_1 ...
# using -f (force) option
# installing: future-0.17.1-py27_0 ...
# using -f (force) option
# installing: futures-3.2.0-py27_0 ...
# using -f (force) option
# installing: glob2-0.6-py27_1 ...
# using -f (force) option
# installing: gmpy2-2.0.8-py27h10f8cd9_2 ...
# using -f (force) option
# installing: greenlet-0.4.15-py27h7b6447c_0 ...
# using -f (force) option
# installing: grin-1.2.1-py27_4 ...
# using -f (force) option
# installing: heapdict-1.0.0-py27_2 ...
# using -f (force) option
# installing: idna-2.8-py27_0 ...
# using -f (force) option
# installing: imagesize-1.1.0-py27_0 ...
# using -f (force) option
# installing: ipaddress-1.0.22-py27_0 ...
# using -f (force) option
# installing: ipython_genutils-0.2.0-py27h89fb69b_0 ...
# using -f (force) option
# installing: itsdangerous-1.1.0-py27_0 ...
# using -f (force) option
# installing: jdcal-1.4-py27_0 ...
# using -f (force) option
# installing: kiwisolver-1.0.1-py27hf484d3e_0 ...
# using -f (force) option
# installing: lazy-object-proxy-1.3.1-py27h14c3975_2 ...
# using -f (force) option
# installing: linecache2-1.0.0-py27_0 ...
# using -f (force) option
# installing: locket-0.2.0-py27h73929a2_1 ...
# using -f (force) option
# installing: lxml-4.3.2-py27hefd8a0e_0 ...
# using -f (force) option
# installing: markupsafe-1.1.1-py27h7b6447c_0 ...
# using -f (force) option
# installing: mccabe-0.6.1-py27_1 ...
# using -f (force) option
# installing: mistune-0.8.4-py27h7b6447c_0 ...
# using -f (force) option
# installing: mkl-service-1.1.2-py27he904b0f_5 ...
# using -f (force) option
# installing: mpmath-1.1.0-py27_0 ...
# using -f (force) option
# installing: msgpack-python-0.6.1-py27hfd86e86_1 ...
# using -f (force) option
# installing: numpy-base-1.16.2-py27hde5b4d6_0 ...
# using -f (force) option
# installing: olefile-0.46-py27_0 ...
# using -f (force) option
# installing: pandocfilters-1.4.2-py27_1 ...
# using -f (force) option
# installing: parso-0.3.4-py27_0 ...
# using -f (force) option
# installing: pep8-1.7.1-py27_0 ...
# using -f (force) option
# installing: pkginfo-1.5.0.1-py27_0 ...
# using -f (force) option
# installing: pluggy-0.9.0-py27_0 ...
# using -f (force) option
# installing: ply-3.11-py27_0 ...
# using -f (force) option
# installing: prometheus_client-0.6.0-py27_0 ...
# using -f (force) option
# installing: psutil-5.6.1-py27h7b6447c_0 ...
# using -f (force) option
# installing: ptyprocess-0.6.0-py27_0 ...
# using -f (force) option
# installing: py-1.8.0-py27_0 ...
# using -f (force) option
# installing: py-lief-0.9.0-py27h7725739_2 ...
# using -f (force) option
# installing: pycodestyle-2.5.0-py27_0 ...
# using -f (force) option
# installing: pycosat-0.6.3-py27h14c3975_0 ...
# using -f (force) option
# installing: pycparser-2.19-py27_0 ...
# using -f (force) option
# installing: pycrypto-2.6.1-py27h14c3975_9 ...
# using -f (force) option
# installing: pycurl-7.43.0.2-py27h1ba5d50_0 ...
# using -f (force) option
# installing: pyflakes-2.1.1-py27_0 ...
# using -f (force) option
# installing: pyodbc-4.0.26-py27he6710b0_0 ...
# using -f (force) option
# installing: pyparsing-2.3.1-py27_0 ...
# using -f (force) option
# installing: pysocks-1.6.8-py27_0 ...
# using -f (force) option
# installing: python-libarchive-c-2.8-py27_6 ...
# using -f (force) option
# installing: pytz-2018.9-py27_0 ...
# using -f (force) option
# installing: pyyaml-5.1-py27h7b6447c_0 ...
# using -f (force) option
# installing: pyzmq-18.0.0-py27he6710b0_0 ...
# using -f (force) option
# installing: qt-5.9.7-h5867ecd_1 ...
# using -f (force) option
# installing: qtpy-1.7.0-py27_1 ...
# using -f (force) option
# installing: rope-0.12.0-py27_0 ...
# using -f (force) option
# installing: ruamel_yaml-0.15.46-py27h14c3975_0 ...
# using -f (force) option
# installing: scandir-1.10.0-py27h7b6447c_0 ...
# using -f (force) option
# installing: send2trash-1.5.0-py27_0 ...
# using -f (force) option
# installing: simplegeneric-0.8.1-py27_2 ...
# using -f (force) option
# installing: sip-4.19.8-py27hf484d3e_0 ...
# using -f (force) option
# installing: six-1.12.0-py27_0 ...
# using -f (force) option
# installing: snowballstemmer-1.2.1-py27h44e2768_0 ...
# using -f (force) option
# installing: sortedcontainers-2.1.0-py27_0 ...
# using -f (force) option
# installing: sphinxcontrib-1.0-py27_1 ...
# using -f (force) option
# installing: sqlalchemy-1.3.1-py27h7b6447c_0 ...
# using -f (force) option
# installing: subprocess32-3.5.3-py27h7b6447c_0 ...
# using -f (force) option
# installing: tblib-1.3.2-py27h51fe5ba_0 ...
# using -f (force) option
# installing: testpath-0.4.2-py27_0 ...
# using -f (force) option
# installing: toolz-0.9.0-py27_0 ...
# using -f (force) option
# installing: tqdm-4.31.1-py27_1 ...
# using -f (force) option
# installing: typing-3.6.6-py27_0 ...
# using -f (force) option
# installing: unicodecsv-0.14.1-py27h5062da9_0 ...
# using -f (force) option
# installing: wcwidth-0.1.7-py27h9e3e1ab_0 ...
# using -f (force) option
# installing: webencodings-0.5.1-py27_1 ...
# using -f (force) option
# installing: werkzeug-0.14.1-py27_0 ...
# using -f (force) option
# installing: wrapt-1.11.1-py27h7b6447c_0 ...
# using -f (force) option
# installing: wurlitzer-1.0.2-py27_0 ...
# using -f (force) option
# installing: xlrd-1.2.0-py27_0 ...
# using -f (force) option
# installing: xlsxwriter-1.1.5-py27_0 ...
# using -f (force) option
# installing: xlwt-1.3.0-py27h3d85d97_0 ...
# using -f (force) option
# installing: zipp-0.3.3-py27_1 ...
# using -f (force) option
# installing: babel-2.6.0-py27_0 ...
# using -f (force) option
# installing: backports.os-0.1.1-py27_0 ...
# using -f (force) option
# installing: backports.shutil_get_terminal_size-1.0.0-py27_2 ...
# using -f (force) option
# installing: cffi-1.12.2-py27h2e261b9_1 ...
# using -f (force) option
# installing: configparser-3.7.3-py27_1 ...
# using -f (force) option
# installing: cycler-0.10.0-py27hc7354d3_0 ...
# using -f (force) option
# installing: cytoolz-0.9.0.1-py27h14c3975_1 ...
# using -f (force) option
# installing: harfbuzz-1.8.8-hffaf4a1_0 ...
# using -f (force) option
# installing: html5lib-1.0.1-py27_0 ...
# using -f (force) option
# installing: jedi-0.13.3-py27_0 ...
# using -f (force) option
# installing: llvmlite-0.28.0-py27hd408876_0 ...
# using -f (force) option
# installing: mkl_random-1.0.2-py27hd81dba3_0 ...
# using -f (force) option
# installing: more-itertools-5.0.0-py27_0 ...
# using -f (force) option
# installing: multipledispatch-0.6.0-py27_0 ...
# using -f (force) option
# installing: nltk-3.4-py27_1 ...
# using -f (force) option
# installing: openpyxl-2.6.1-py27_1 ...
# using -f (force) option
# installing: packaging-19.0-py27_0 ...
# using -f (force) option
# installing: partd-0.3.10-py27_1 ...
# using -f (force) option
# installing: pathlib2-2.3.3-py27_0 ...
# using -f (force) option
# installing: pexpect-4.6.0-py27_0 ...
# using -f (force) option
# installing: pillow-5.4.1-py27h34e0f95_0 ...
# using -f (force) option
# installing: pycairo-1.18.0-py27h2a1e443_0 ...
# using -f (force) option
# installing: pyqt-5.9.2-py27h05f1152_2 ...
# using -f (force) option
# installing: pyrsistent-0.14.11-py27h7b6447c_0 ...
# using -f (force) option
# installing: python-dateutil-2.8.0-py27_0 ...
# using -f (force) option
# installing: qtawesome-0.5.7-py27_1 ...
# using -f (force) option
# installing: setuptools-40.8.0-py27_0 ...
# using -f (force) option
# installing: singledispatch-3.4.0.3-py27h9bcb476_0 ...
# using -f (force) option
# installing: sortedcollections-1.1.2-py27_0 ...
# using -f (force) option
# installing: sphinxcontrib-websupport-1.1.0-py27_1 ...
# using -f (force) option
# installing: ssl_match_hostname-3.7.0.1-py27_0 ...
# using -f (force) option
# installing: sympy-1.3-py27_0 ...
# using -f (force) option
# installing: traceback2-1.4.0-py27_0 ...
# using -f (force) option
# installing: traitlets-4.3.2-py27hd6ce930_0 ...
# using -f (force) option
# installing: zict-0.1.4-py27_0 ...
# using -f (force) option
# installing: backports.functools_lru_cache-1.5-py27_1 ...
# using -f (force) option
# installing: bleach-3.1.0-py27_0 ...
# using -f (force) option
# installing: clyent-1.2.2-py27_1 ...
# using -f (force) option
# installing: cryptography-2.6.1-py27h1ba5d50_0 ...
# using -f (force) option
# installing: cython-0.29.6-py27he6710b0_0 ...
# using -f (force) option
# installing: entrypoints-0.3-py27_0 ...
# using -f (force) option
# installing: get_terminal_size-1.0.0-haa9412d_0 ...
# using -f (force) option
# installing: gevent-1.4.0-py27h7b6447c_0 ...
# using -f (force) option
# installing: importlib_metadata-0.8-py27_0 ...
# using -f (force) option
# installing: jinja2-2.10-py27_0 ...
# using -f (force) option
# installing: jsonschema-3.0.1-py27_0 ...
# using -f (force) option
# installing: jupyter_core-4.4.0-py27_0 ...
# using -f (force) option
# installing: navigator-updater-0.2.1-py27_0 ...
# using -f (force) option
# installing: networkx-2.2-py27_1 ...
# using -f (force) option
# installing: nose-1.3.7-py27_2 ...
# using -f (force) option
# installing: pango-1.42.4-h049681c_0 ...
# using -f (force) option
# installing: pickleshare-0.7.5-py27_0 ...
# using -f (force) option
# installing: pygments-2.3.1-py27_0 ...
# using -f (force) option
# installing: pytest-4.3.1-py27_0 ...
# using -f (force) option
# installing: tornado-5.1.1-py27h7b6447c_0 ...
# using -f (force) option
# installing: unittest2-1.1.0-py27_0 ...
# using -f (force) option
# installing: wheel-0.33.1-py27_0 ...
# using -f (force) option
# installing: astroid-1.6.5-py27_0 ...
# using -f (force) option
# installing: conda-verify-3.1.1-py27_0 ...
# using -f (force) option
# installing: distributed-1.26.0-py27_1 ...
# using -f (force) option
# installing: flask-1.0.2-py27_1 ...
# using -f (force) option
# installing: isort-4.3.16-py27_0 ...
# using -f (force) option
# installing: jupyter_client-5.2.4-py27_0 ...
# using -f (force) option
# installing: nbformat-4.4.0-py27hed7f2b2_0 ...
# using -f (force) option
# installing: path.py-11.5.0-py27_0 ...
# using -f (force) option
# installing: pip-19.0.3-py27_0 ...
# using -f (force) option
# installing: prompt_toolkit-1.0.15-py27h1b593e1_0 ...
# using -f (force) option
# installing: pyopenssl-19.0.0-py27_0 ...
# using -f (force) option
# installing: soupsieve-1.8-py27_0 ...
# using -f (force) option
# installing: terminado-0.8.1-py27_1 ...
# using -f (force) option
# installing: beautifulsoup4-4.7.1-py27_1 ...
# using -f (force) option
# installing: ipython-5.8.0-py27_0 ...
# using -f (force) option
# installing: nbconvert-5.4.1-py27_3 ...
# using -f (force) option
# installing: pylint-1.9.2-py27_0 ...
# using -f (force) option
# installing: urllib3-1.24.1-py27_0 ...
# using -f (force) option
# installing: ipykernel-4.10.0-py27_0 ...
# using -f (force) option
# installing: requests-2.21.0-py27_0 ...
# using -f (force) option
# installing: anaconda-client-1.7.2-py27_0 ...
# using -f (force) option
# installing: conda-4.6.11-py27_0 ...
# using -f (force) option
# installing: jupyter_console-5.2.0-py27_1 ...
# using -f (force) option
# installing: notebook-5.7.8-py27_0 ...
# using -f (force) option
# installing: qtconsole-4.4.3-py27_0 ...
# using -f (force) option
# installing: sphinx-1.8.5-py27_0 ...
# using -f (force) option
# installing: spyder-kernels-0.4.2-py27_0 ...
# using -f (force) option
# installing: anaconda-navigator-1.9.7-py27_0 ...
# using -f (force) option
# installing: anaconda-project-0.8.2-py27_0 ...
# using -f (force) option
# installing: conda-build-3.17.8-py27_0 ...
# using -f (force) option
# installing: jupyterlab_launcher-0.11.2-py27h28b3542_0 ...
# using -f (force) option
# installing: numpydoc-0.8.0-py27_0 ...
# using -f (force) option
# installing: widgetsnbextension-3.4.2-py27_0 ...
# using -f (force) option
# installing: ipywidgets-7.4.2-py27_0 ...
# using -f (force) option
# installing: jupyterlab-0.33.11-py27_0 ...
# using -f (force) option
# installing: spyder-3.3.3-py27_0 ...
# using -f (force) option
# installing: _ipyw_jlab_nb_ext_conf-0.1.0-py27_0 ...
# using -f (force) option
# installing: jupyter-1.0.0-py27_7 ...
# using -f (force) option
# installing: astropy-2.0.9-py27hdd07704_0 ...
# using -f (force) option
# installing: bokeh-1.0.4-py27_0 ...
# using -f (force) option
# installing: bottleneck-1.2.1-py27h035aef0_1 ...
# using -f (force) option
# installing: h5py-2.9.0-py27h7918eee_0 ...
# using -f (force) option
# installing: imageio-2.5.0-py27_0 ...
# using -f (force) option
# installing: matplotlib-2.2.3-py27hb69df0a_0 ...
# using -f (force) option
# installing: mkl_fft-1.0.10-py27ha843d7b_0 ...
# using -f (force) option
# installing: numpy-1.16.2-py27h7e9f1db_0 ...
# using -f (force) option
# installing: numba-0.43.1-py27h962f231_0 ...
# using -f (force) option
# installing: numexpr-2.6.9-py27h9e4a6bb_0 ...
# using -f (force) option
# installing: pandas-0.24.2-py27he6710b0_0 ...
# using -f (force) option
# installing: pywavelets-1.0.2-py27hdd07704_0 ...
# using -f (force) option
# installing: scipy-1.2.1-py27h7c811a0_0 ...
# using -f (force) option
# installing: bkcharts-0.2-py27h241ae91_0 ...
# using -f (force) option
# installing: dask-1.1.4-py27_1 ...
# using -f (force) option
# installing: patsy-0.5.1-py27_0 ...
# using -f (force) option
# installing: pytables-3.5.1-py27h71ec239_0 ...
# using -f (force) option
# installing: scikit-image-0.14.2-py27he6710b0_0 ...
# using -f (force) option
# installing: scikit-learn-0.20.3-py27hd81dba3_0 ...
# using -f (force) option
# installing: statsmodels-0.9.0-py27h035aef0_0 ...
# using -f (force) option
# installing: seaborn-0.9.0-py27_0 ...
# using -f (force) option
# installing: anaconda-2019.03-py27_0 ...
# using -f (force) option
# using -f (force) option
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Anaconda2.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Anaconda2: /content/anaconda2
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /content/anaconda2
#
#   added / updated specs:
#     - pyyaml=3.12
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     ca-certificates-2021.1.19  |       h06a4308_1         125 KB
#     certifi-2020.6.20          |     pyhd3eb1b0_3         159 KB
#     conda-4.8.4                |           py27_0         3.0 MB
#     conda-package-handling-1.6.0|   py27h7b6447c_0         865 KB
#     openssl-1.1.1k             |       h27cfd23_0         3.8 MB
#     pyyaml-3.12                |   py27h14c3975_1         173 KB
#     ------------------------------------------------------------
#                                            Total:         8.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py27h7b6447c_0
#
# The following packages will be REMOVED:
#
#   anaconda-2019.03-py27_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                               2019.1.23-0 --> 2021.1.19-h06a4308_1
#   certifi            pkgs/main/linux-64::certifi-2019.3.9-~ --> pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#   conda                                       4.6.11-py27_0 --> 4.8.4-py27_0
#   openssl                                 1.1.1b-h7b6447c_1 --> 1.1.1k-h27cfd23_0
#
# The following packages will be DOWNGRADED:
#
#   pyyaml                                 5.1-py27h7b6447c_0 --> 3.12-py27h14c3975_1
#
#
#
# Downloading and Extracting Packages
# pyyaml-3.12          | 173 KB    | : 100% 1.0/1 [00:00<00:00,  4.19s/it]
# conda-4.8.4          | 3.0 MB    | : 100% 1.0/1 [00:02<00:00,  2.36s/it]
# certifi-2020.6.20    | 159 KB    | : 100% 1.0/1 [00:00<00:00,  8.78it/s]
# conda-package-handli | 865 KB    | : 100% 1.0/1 [00:00<00:00,  1.09it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 31.54it/s]
# ca-certificates-2021 | 125 KB    | : 100% 1.0/1 [00:00<00:00, 15.56it/s]
# openssl-1.1.1k       | 3.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.59s/it]
# done
# done
# done
# done
# -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::numba==0.43.1=py27h962f231_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /content/anaconda2
#
#   added / updated specs:
#     - mkl-include
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mkl-include-2020.2         |              256         610 KB
#     tbb-2020.3                 |       hfd86e86_0         1.4 MB
#     ------------------------------------------------------------
#                                            Total:         2.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   mkl-include        pkgs/main/linux-64::mkl-include-2020.2-256
#   tbb                pkgs/main/linux-64::tbb-2020.3-hfd86e86_0
#
#
#
# Downloading and Extracting Packages
# tbb-2020.3           | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.94it/s]
# mkl-include-2020.2   | 610 KB    | : 100% 1.0/1 [00:00<00:00,  1.13it/s]
# done
# done
# done
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /content/anaconda2
#
#   added / updated specs:
#     - cudatoolkit=10.0
#     - pytorch=1.0.1
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-10.0.130       |                0       380.0 MB
#     ninja-1.9.0                |   py27hfd86e86_0         1.6 MB
#     pytorch-1.0.1              |py2.7_cuda10.0.130_cudnn7.4.2_2       375.4 MB  pytorch
#     torchvision-0.2.2          |             py_3          44 KB  pytorch
#     ------------------------------------------------------------
#                                            Total:       757.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/linux-64::cudatoolkit-10.0.130-0
#   ninja              pkgs/main/linux-64::ninja-1.9.0-py27hfd86e86_0
#   pytorch            pytorch/linux-64::pytorch-1.0.1-py2.7_cuda10.0.130_cudnn7.4.2_2
#   torchvision        pytorch/noarch::torchvision-0.2.2-py_3
#
#
#
# Downloading and Extracting Packages
# torchvision-0.2.2    | 44 KB     | : 100% 1.0/1 [00:02<00:00,  2.08s/it]
# ninja-1.9.0          | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
# cudatoolkit-10.0.130 | 380.0 MB  | : 100% 1.0/1 [00:51<00:00, 51.18s/it]
# pytorch-1.0.1        | 375.4 MB  | : 100% 0.995746221301/1 [00:29<00:00, 24.93s/it]

# %% [markdown]
# Check whether the system dependencies are installed correctly:

# %%
# some sanity checks
# !conda --version
# !protoc --version
# !gcc-4.9 --version
# Out:
# conda 4.8.4
# libprotoc 3.5.1
# gcc-4.9 (GCC) 4.9.1
# Copyright (C) 2014 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading https://files.pythonhosted.org/packages/95/c8/a44ff37bbff247d1015d441cd185cc4e8c79cccecd610785ef0a30cb3ef6/opencv_contrib_python-4.2.0.32-cp27-cp27mu-manylinux1_x86_64.whl (34.2MB)
#     100% |████████████████████████████████| 34.2MB 1.1MB/s
# Requirement already satisfied: numpy>=1.11.1 in ./anaconda2/lib/python2.7/site-packages (from opencv-contrib-python) (1.16.2)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.2.0.32

# %% [markdown]
# # Clone the DensePose project and build it:

# %%
import os
from os.path import exists, join, basename, splitext

git_repo_url = 'https://github.com/facebookresearch/DensePose.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # clone project
  # !git clone -q --depth 1 $git_repo_url
  # install dependencies
  # !cd $project_name && pip install -q -r requirements.txt
  # update CMakeLists.txt
  cmakelists_txt_content = """
cmake_minimum_required(VERSION 2.8.12 FATAL_ERROR)
set(Caffe2_DIR "/content/anaconda2/lib/python2.7/site-packages/torch/share/cmake/Caffe2/")
find_package(Caffe2 REQUIRED)

include_directories("/content/anaconda2/lib/python2.7/site-packages/torch/lib/include")
include_directories("/content/anaconda2/include")
include_directories("/content/pytorch")

add_library(libprotobuf STATIC IMPORTED)
set(PROTOBUF_LIB "/content/anaconda2/lib/libprotobuf.a")
set_property(TARGET libprotobuf PROPERTY IMPORTED_LOCATION "${PROTOBUF_LIB}")

if (${CAFFE2_VERSION} VERSION_LESS 0.8.2)
  # Pre-0.8.2 caffe2 does not have proper interface libraries set up, so we
  # will rely on the old path.
  message(WARNING
      "You are using an older version of Caffe2 (version " ${CAFFE2_VERSION}
      "). Please consider moving to a newer version.")
  include(cmake/legacy/legacymake.cmake)
  return()
endif()

# Add compiler flags.
set(CMAKE_C_FLAGS "${CMAKE_C_FLAGS} -std=c11")
set(CMAKE_CXX_FLAGS "${CMAKE_CXX_FLAGS} -std=c++11 -O2 -fPIC -Wno-narrowing")

# Print configuration summary.
include(cmake/Summary.cmake)
detectron_print_config_summary()

# Collect custom ops sources.
file(GLOB CUSTOM_OPS_CPU_SRCS ${CMAKE_CURRENT_SOURCE_DIR}/detectron/ops/*.cc)
file(GLOB CUSTOM_OPS_GPU_SRCS ${CMAKE_CURRENT_SOURCE_DIR}/detectron/ops/*.cu)

# Install custom CPU ops lib.
add_library(
     caffe2_detectron_custom_ops SHARED
     ${CUSTOM_OPS_CPU_SRCS})

target_link_libraries(caffe2_detectron_custom_ops caffe2_library libprotobuf)
install(TARGETS caffe2_detectron_custom_ops DESTINATION lib)

# Install custom GPU ops lib, if gpu is present.
if (CAFFE2_USE_CUDA OR CAFFE2_FOUND_CUDA)
  # Additional -I prefix is required for CMake versions before commit (< 3.7):
  # https://github.com/Kitware/CMake/commit/7ded655f7ba82ea72a82d0555449f2df5ef38594
  list(APPEND CUDA_INCLUDE_DIRS -I${CAFFE2_INCLUDE_DIRS})
  CUDA_ADD_LIBRARY(
      caffe2_detectron_custom_ops_gpu SHARED
      ${CUSTOM_OPS_CPU_SRCS}
      ${CUSTOM_OPS_GPU_SRCS})

  target_link_libraries(caffe2_detectron_custom_ops_gpu caffe2_gpu_library libprotobuf)
  install(TARGETS caffe2_detectron_custom_ops_gpu DESTINATION lib)
endif()"""
  open(join(project_name, 'CMakeLists.txt'), 'w').write(cmakelists_txt_content)
  # build
  # !cd $project_name && make
  # !cd $project_name && make ops
  # download dense pose data
  # !cd $project_name/DensePoseData && bash get_densepose_uv.sh

# %% [markdown]
# Check whether the DensePose installation was successful:

# %%
# !python2 $project_name/detectron/tests/test_spatial_narrow_as_op.py
# !python2 $project_name/detectron/tests/test_zero_even_op.py
# Out:
# No handlers could be found for logger "caffe2.python.net_drawer"
# net_drawer will not run correctly. Please install the correct dependencies.
# [E init_intrinsics_check.cc:43] CPU feature avx is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# [E init_intrinsics_check.cc:43] CPU feature avx2 is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# [E init_intrinsics_check.cc:43] CPU feature fma is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# Found Detectron ops lib: /content/anaconda2/lib/python2.7/site-packages/lib/libcaffe2_detectron_ops_gpu.so
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 3.600s
#
# OK
# [E init_intrinsics_check.cc:43] CPU feature avx is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# [E init_intrinsics_check.cc:43] CPU feature avx2 is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# [E init_intrinsics_check.cc:43] CPU feature fma is present on your machine, but the Caffe2 binary is not compiled with it. It means you may not get the full speed of your CPU.
# ............
# ----------------------------------------------------------------------
# Ran 12 tests in 2.804s
#
# OK

# %% [markdown]
# ### Convert the video into images

# %% [markdown]
# create file structure for storing data and upload video
# > - test_samples: top level directory to store data
# > - overlay_figs: store frame image with IUV contour
# > - densepose_mask: store raw results of DensePose
# > - video2images: store decomposed images from the video

# %%
% cd /content
% mkdir test_samples
% cd test_samples
% mkdir densepose_mask overlay_figs video2images
# upload test_video.mp4
from google.colab import files
uploaded = files.upload()
# Out:
# /content
# mkdir: cannot create directory ‘test_samples’: File exists
# /content/test_samples
# mkdir: cannot create directory ‘densepose_mask’: File exists
# mkdir: cannot create directory ‘overlay_figs’: File exists
# mkdir: cannot create directory ‘video2images’: File exists
#      <input type="file" id="files-f483c439-6887-4fc8-aa7e-84c63aece619" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f483c439-6887-4fc8-aa7e-84c63aece619">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# Decompose the video into images
# - the video is captured very 0.5 sec, to make smoother video, decrease $frameRate

# %%
% cd /content/

import cv2
import os

ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(ROOT_DIR, "test_samples")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "video2images")
vidcap = cv2.VideoCapture(os.path.join(VIDEO_DIR, 'test.avi'))

try:
  if not os.path.exists(VIDEO_SAVE_DIR):
    os.makedirs(VIDEO_SAVE_DIR)
except OSError:
  print ('Error: Creating directory of data')

def getFrame(sec):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        name = "image"+str(count)+".jpg"
        name = os.path.join(VIDEO_SAVE_DIR, name)
        cv2.imwrite(name, image)     # save frame as JPG file
    return hasFrames

sec = 0
frameRate = 0.2 #//it will capture image in each 0.5 second
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

print('complete')
# Out:
# /content
# complete

# %% [markdown]
# ### Detect poses in the uploaded video

# %% [markdown]
# run infer_simple.py multiple times on each frame

# %%
# count number of frames in the video
import os
dir = '/content/test_samples/video2images'
list = os.listdir(dir) 
n = len(list)

% cd $project_name
for i in range(1,n+1):
    # !cd $project_name && python2 tools/infer_simple.py \
    # !python2 tools/infer_simple.py \
        --cfg configs/DensePose_ResNet101_FPN_s1x-e2e.yaml \
        --output-dir ../test_samples/densepose_mask \
        --image-ext jpg \
        --wts https://dl.fbaipublicfiles.com/densepose/DensePose_ResNet101_FPN_s1x-e2e.pkl \
        ../test_samples/video2images/image"$i".jpg
% cd ..
# Out:
# [Errno 2] No such file or directory: '$project_name'
# /content
# /

# %% [markdown]
# ### Visualize and store the result:

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# count number of frames in the video
dir = '/content/test_samples/video2images'
list = os.listdir(dir) 
n = len(list)

for i in range(1,n+1):
    source = '../test_samples/video2images/image{}.jpg'.format(i)
    iuv_img = '../test_samples/densepose_mask/image{}_IUV.png'.format(i)
    save = '../test_samples/overlay_figs/plot{}.png'.format(i)
    im  = cv2.imread(join(project_name, source))
    IUV = cv2.imread(join(project_name, iuv_img))
    # INDS = cv2.imread(join(project_name, '../test_samples/densepose_mask/image{}_INDS.png'),  0)

    # fig = plt.figure(figsize=[20, 20])
    fig = plt.figure()
    plt.imshow( im[:,:,::-1] )
    plt.contour( IUV[:,:,1]/256.,10, linewidths = 1 )
    plt.contour( IUV[:,:,2]/256.,10, linewidths = 1 )
    plt.axis('off') ; 
    plt.show()
    fig.savefig(join(project_name,save))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-31209ac1f3d5> in <module>()
#       5 # count number of frames in the video
#       6 dir = '/content/test_samples/video2images'
# ----> 7 list = os.listdir(dir)
#       8 n = len(list)
#       9
#
# NameError: name 'os' is not defined

# %% [markdown]
# ### Generate video from processed images

# %% [markdown]
# combine the processed images to a single video

# %%
% cd /content/

# Generate the video from processed image frames.
def make_video(outvid, images=None, fps=30, size=None, is_color=True, format="FMP4"):
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
        vid.release()
    return vid

import glob
import os

# Directory of images to run detection on
ROOT_DIR = os.getcwd()
VIDEO_DIR = os.path.join(ROOT_DIR, "test_samples")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "overlay_figs")
print(VIDEO_SAVE_DIR)

# Make sure the frames are ordered in the same way as they are extracted from the original video
images = glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*'))
# Sort the images by integer index
images = sorted(images, key=lambda x: os.path.split(x)[1][:-3])

# Make video
outvid = os.path.join(VIDEO_DIR, "test_out.mp4")
make_video(outvid, images, fps=30)
print('complete')
# Out:
# /content
# /content/test_samples/overlay_figs
# complete

# %% [markdown]
# ### Download outputs

# %%
# !zip -r /content/test_samples.zip /content/test_samples/video2images/
from google.colab import files
files.download('/content/test_samples.zip')
# Out:
# updating: content/test_samples/video2images/ (stored 0%)
